# %%
import numpy as np  
import pandas as pd
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt 

samples = 10000
features = 1

X, y = make_regression(n_samples=samples, n_features=features, n_informative=10, n_targets=1, bias=0.0, effective_rank=None, tail_strength=0.5, noise=0.9, shuffle=True, coef=False, random_state=1345)

features = pd.DataFrame(X, columns=list('a'))
values = pd.DataFrame({'labels': y})

dataset = features.join(values)

dataset.head(5)
plt.scatter(dataset['a'], dataset['labels'], marker='.')  
plt.show() 
#dataset.to_csv(path_or_buf ='./regresion_f1_dataset.csv', index = False)
